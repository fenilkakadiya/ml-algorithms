# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import warnings 
warnings.filterwarnings("ignore")

# %%
# !pip install plotly
# Out:
# Collecting plotly
#   Downloading plotly-6.5.0-py3-none-any.whl.metadata (8.5 kB)
# Collecting narwhals>=1.15.1 (from plotly)
#   Downloading narwhals-2.14.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: packaging in c:\users\fenil\appdata\local\programs\python\python313\lib\site-packages (from plotly) (25.0)
# Downloading plotly-6.5.0-py3-none-any.whl (9.9 MB)
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    ------ --------------------------------- 1.6/9.9 MB 11.3 MB/s eta 0:00:01
#    --------------- ------------------------ 3.9/9.9 MB 11.2 MB/s eta 0:00:01
#    ------------------------- -------------- 6.3/9.9 MB 11.2 MB/s eta 0:00:01
#    --------------------------------- ------ 8.4/9.9 MB 11.2 MB/s eta 0:00:01
#    ---------------------------------------- 9.9/9.9 MB 10.9 MB/s  0:00:00
# Downloading narwhals-2.14.0-py3-none-any.whl (430 kB)
# Installing collected packages: narwhals, plotly
#
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    ---------------------------------------- 2/2 [plotly]
#
# Successfully installed narwhals-2.14.0 plotly-6.5.0

# %%
df = pd.read_csv("Travel.csv")

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\fenil'

# %%
df.head()
# Out:
#    CustomerID  ProdTaken   Age    TypeofContact  CityTier  DurationOfPitch  \
# 0      200000          1  41.0     Self Enquiry         3              6.0
# 1      200001          0  49.0  Company Invited         1             14.0
# 2      200002          1  37.0     Self Enquiry         1              8.0
# 3      200003          0  33.0  Company Invited         1              9.0
# 4      200004          0   NaN     Self Enquiry         1              8.0
#
#        Occupation  Gender  NumberOfPersonVisiting  NumberOfFollowups  \
# 0        Salaried  Female                       3                3.0
# 1        Salaried    Male                       3                4.0
# 2     Free Lancer    Male                       3                4.0
# 3        Salaried  Female                       2                3.0
# 4  Small Business    Male                       2                3.0
#
#   ProductPitched  PreferredPropertyStar MaritalStatus  NumberOfTrips  \
# 0         Deluxe                    3.0        Single            1.0
# 1         Deluxe                    4.0      Divorced            2.0
# 2          Basic                    3.0        Single            7.0
# 3          Basic                    3.0      Divorced            2.0
# 4          Basic                    4.0      Divorced            1.0
#
#    Passport  PitchSatisfactionScore  OwnCar  NumberOfChildrenVisiting  \
# 0         1                       2       1                       0.0
# 1         0                       3       1                       2.0
# 2         1                       3       0                       0.0
# 3         1                       5       1                       1.0
# 4         0                       5       1                       0.0
#
#   Designation  MonthlyIncome
# 0     Manager        20993.0
# 1     Manager        20130.0
# 2   Executive        17090.0
# 3   Executive        17909.0
# 4   Executive        18468.0

# %%
df.isnull().sum()
# Out:
# CustomerID                    0
# ProdTaken                     0
# Age                         226
# TypeofContact                25
# CityTier                      0
# DurationOfPitch             251
# Occupation                    0
# Gender                        0
# NumberOfPersonVisiting        0
# NumberOfFollowups            45
# ProductPitched                0
# PreferredPropertyStar        26
# MaritalStatus                 0
# NumberOfTrips               140
# Passport                      0
# PitchSatisfactionScore        0
# OwnCar                        0
# NumberOfChildrenVisiting     66
# Designation                   0
# MonthlyIncome               233
# dtype: int64

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Male       2916
# Female     1817
# Fe Male     155
# Name: count, dtype: int64

# %%
df['MaritalStatus'].value_counts()
# Out:
# MaritalStatus
# Married      2340
# Divorced      950
# Single        916
# Unmarried     682
# Name: count, dtype: int64

# %%
df['TypeofContact'].value_counts()
# Out:
# TypeofContact
# Self Enquiry       3444
# Company Invited    1419
# Name: count, dtype: int64

# %%
df['Gender'] = df['Gender'].replace('Fe Male','Female')
df['MaritalStatus'] = df['MaritalStatus'].replace('Single','Unmarried')

# %%
df.head(50)
# Out:
#     CustomerID  ProdTaken   Age    TypeofContact  CityTier  DurationOfPitch  \
# 0       200000          1  41.0     Self Enquiry         3              6.0
# 1       200001          0  49.0  Company Invited         1             14.0
# 2       200002          1  37.0     Self Enquiry         1              8.0
# 3       200003          0  33.0  Company Invited         1              9.0
# 4       200004          0   NaN     Self Enquiry         1              8.0
# 5       200005          0  32.0  Company Invited         1              8.0
# 6       200006          0  59.0     Self Enquiry         1              9.0
# 7       200007          0  30.0     Self Enquiry         1             30.0
# 8       200008          0  38.0  Company Invited         1             29.0
# 9       200009          0  36.0     Self Enquiry         1             33.0
# 10      200010          0  35.0     Self Enquiry         1             22.0
# 11      200011          0   NaN     Self Enquiry         1             21.0
# 12      200012          0  31.0     Self Enquiry         1             32.0
# 13      200013          0  34.0     Self Enquiry         1             25.0
# 14      200014          1  28.0     Self Enquiry         1             30.0
# 15      200015          0  29.0     Self Enquiry         1             27.0
# 16      200016          0  32.0     Self Enquiry         1             11.0
# 17      200017          0  22.0  Company Invited         1             22.0
# 18      200018          0  53.0     Self Enquiry         3              8.0
# 19      200019          0   NaN     Self Enquiry         1              8.0
# 20      200020          0   NaN  Company Invited         1             17.0
# 21      200021          1   NaN     Self Enquiry         3             15.0
# 22      200022          0  34.0     Self Enquiry         1             13.0
# 23      200023          0  21.0     Self Enquiry         1             21.0
# 24      200024          1  34.0     Self Enquiry         1             12.0
# 25      200025          0  53.0     Self Enquiry         1             11.0
# 26      200026          1   NaN  Company Invited         1             22.0
# 27      200027          0  42.0     Self Enquiry         3             14.0
# 28      200028          0  44.0     Self Enquiry         1             13.0
# 29      200029          0  46.0     Self Enquiry         3              8.0
# 30      200030          0  33.0     Self Enquiry         1              8.0
# 31      200031          0  44.0     Self Enquiry         1             16.0
# 32      200032          0  30.0     Self Enquiry         1             15.0
# 33      200033          1  39.0     Self Enquiry         3             11.0
# 34      200034          1  24.0     Self Enquiry         1              6.0
# 35      200035          0  43.0     Self Enquiry         1              8.0
# 36      200036          1  50.0     Self Enquiry         3              9.0
# 37      200037          0  35.0     Self Enquiry         3              8.0
# 38      200038          0  36.0     Self Enquiry         1             11.0
# 39      200039          0  33.0  Company Invited         3              6.0
# 40      200040          0  35.0     Self Enquiry         1             10.0
# 41      200041          0  27.0     Self Enquiry         1              8.0
# 42      200042          1  26.0     Self Enquiry         1             31.0
# 43      200043          0  27.0  Company Invited         3             14.0
# 44      200044          0   NaN  Company Invited         1              6.0
# 45      200045          1  41.0     Self Enquiry         1             18.0
# 46      200046          0  34.0  Company Invited         3              NaN
# 47      200047          0  37.0     Self Enquiry         1             25.0
# 48      200048          0  46.0  Company Invited         3             11.0
# 49      200049          0  35.0     Self Enquiry         1             14.0
#
#         Occupation  Gender  NumberOfPersonVisiting  NumberOfFollowups  \
# 0         Salaried  Female                       3                3.0
# 1         Salaried    Male                       3                4.0
# 2      Free Lancer    Male                       3                4.0
# 3         Salaried  Female                       2                3.0
# 4   Small Business    Male                       2                3.0
# 5         Salaried    Male                       3                3.0
# 6   Small Business  Female                       2                2.0
# 7         Salaried    Male                       3                3.0
# 8         Salaried    Male                       2                4.0
# 9   Small Business    Male                       3                3.0
# 10  Small Business    Male                       2                2.0
# 11        Salaried  Female                       2                4.0
# 12        Salaried    Male                       2                3.0
# 13  Small Business    Male                       3                3.0
# 14        Salaried    Male                       2                4.0
# 15        Salaried  Female                       2                2.0
# 16        Salaried    Male                       3                2.0
# 17  Small Business    Male                       3                2.0
# 18        Salaried  Female                       3                4.0
# 19        Salaried    Male                       2                3.0
# 20        Salaried  Female                       3                2.0
# 21        Salaried    Male                       2                4.0
# 22        Salaried  Female                       2                3.0
# 23        Salaried    Male                       3                3.0
# 24  Small Business    Male                       2                3.0
# 25        Salaried  Female                       2                3.0
# 26        Salaried  Female                       3                5.0
# 27  Small Business    Male                       2                3.0
# 28  Small Business  Female                       2                4.0
# 29  Small Business  Female                       2                3.0
# 30  Small Business    Male                       3                3.0
# 31        Salaried    Male                       2                3.0
# 32  Small Business    Male                       2                4.0
# 33  Large Business    Male                       2                3.0
# 34  Small Business    Male                       3                3.0
# 35  Small Business  Female                       3                2.0
# 36  Small Business    Male                       2                4.0
# 37  Small Business  Female                       3                3.0
# 38        Salaried  Female                       2                4.0
# 39        Salaried  Female                       2                2.0
# 40        Salaried    Male                       3                3.0
# 41        Salaried  Female                       2                3.0
# 42        Salaried    Male                       2                5.0
# 43        Salaried    Male                       2                3.0
# 44  Small Business  Female                       2                3.0
# 45  Large Business  Female                       2                3.0
# 46  Small Business    Male                       3                3.0
# 47        Salaried    Male                       3                3.0
# 48  Small Business    Male                       3                3.0
# 49        Salaried    Male                       2                2.0
#
#    ProductPitched  PreferredPropertyStar MaritalStatus  NumberOfTrips  \
# 0          Deluxe                    3.0     Unmarried            1.0
# 1          Deluxe                    4.0      Divorced            2.0
# 2           Basic                    3.0     Unmarried            7.0
# 3           Basic                    3.0      Divorced            2.0
# 4           Basic                    4.0      Divorced            1.0
# 5           Basic                    3.0     Unmarried            1.0
# 6           Basic                    5.0      Divorced            5.0
# 7           Basic                    3.0       Married            2.0
# 8        Standard                    3.0     Unmarried            1.0
# 9          Deluxe                    3.0      Divorced            7.0
# 10          Basic                    4.0      Divorced            1.0
# 11         Deluxe                    3.0     Unmarried            1.0
# 12          Basic                    3.0       Married            2.0
# 13          Basic                    3.0       Married            1.0
# 14          Basic                    3.0     Unmarried            6.0
# 15       Standard                    5.0       Married            2.0
# 16          Basic                    4.0       Married            1.0
# 17          Basic                    3.0       Married            2.0
# 18   Super Deluxe                    3.0      Divorced            3.0
# 19          Basic                    3.0     Unmarried            6.0
# 20         Deluxe                    3.0       Married            1.0
# 21         Deluxe                    5.0     Unmarried            1.0
# 22       Standard                    4.0     Unmarried            1.0
# 23          Basic                    3.0     Unmarried            2.0
# 24          Basic                    5.0     Unmarried            3.0
# 25           King                    3.0       Married            5.0
# 26          Basic                    5.0     Unmarried            2.0
# 27         Deluxe                    4.0      Divorced            1.0
# 28       Standard                    3.0      Divorced            4.0
# 29           King                    5.0     Unmarried            4.0
# 30          Basic                    3.0     Unmarried            5.0
# 31         Deluxe                    3.0      Divorced            3.0
# 32          Basic                    3.0     Unmarried            2.0
# 33         Deluxe                    3.0      Divorced            4.0
# 34          Basic                    3.0      Divorced            3.0
# 35          Basic                    3.0       Married            2.0
# 36          Basic                    3.0      Divorced            2.0
# 37          Basic                    3.0      Divorced            2.0
# 38          Basic                    NaN      Divorced            1.0
# 39         Deluxe                    5.0      Divorced            3.0
